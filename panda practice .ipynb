# %%
import numpy as np
import pandas as pd

# %%
dic= { "Name": ["Ram", "Shyam", "Sameer", "Kajal"],
      "Roll no": [1,2,3,4],
    "Grades": ["A", "B", "C", "С"],
"Email":["abc@xyz.com","def@xyz.com","ghi@xyz.com","jkl@xyz.com"]}
dic
# Out:
# {'Name': ['Ram', 'Shyam', 'Sameer', 'Kajal'],
#  'Roll no': [1, 2, 3, 4],
#  'Grades': ['A', 'B', 'C', 'С'],
#  'Email': ['abc@xyz.com', 'def@xyz.com', 'ghi@xyz.com', 'jkl@xyz.com']}

# %%
df= pd.DataFrame(dic)
df
# Out:
#      Name  Roll no Grades        Email
# 0     Ram        1      A  abc@xyz.com
# 1   Shyam        2      B  def@xyz.com
# 2  Sameer        3      C  ghi@xyz.com
# 3   Kajal        4      С  jkl@xyz.com

# %%
df.head()
# Out:
#      Name  Roll no Grades        Email
# 0     Ram        1      A  abc@xyz.com
# 1   Shyam        2      B  def@xyz.com
# 2  Sameer        3      C  ghi@xyz.com
# 3   Kajal        4      С  jkl@xyz.com

# %%
df.head(2)
# Out:
#     Name  Roll no Grades        Email
# 0    Ram        1      A  abc@xyz.com
# 1  Shyam        2      B  def@xyz.com

# %%
df.describe()
# Out:
#         Roll no
# count  4.000000
# mean   2.500000
# std    1.290994
# min    1.000000
# 25%    1.750000
# 50%    2.500000
# 75%    3.250000
# max    4.000000

# %%
df.tail(4)
# Out:
#      Name  Roll no Grades        Email
# 0     Ram        1      A  abc@xyz.com
# 1   Shyam        2      B  def@xyz.com
# 2  Sameer        3      C  ghi@xyz.com
# 3   Kajal        4      С  jkl@xyz.com

# %%
df.tail()
# Out:
#      Name  Roll no Grades        Email
# 0     Ram        1      A  abc@xyz.com
# 1   Shyam        2      B  def@xyz.com
# 2  Sameer        3      C  ghi@xyz.com
# 3   Kajal        4      С  jkl@xyz.com

# %%
df.head()
# Out:
#      Name  Roll no Grades        Email
# 0     Ram        1      A  abc@xyz.com
# 1   Shyam        2      B  def@xyz.com
# 2  Sameer        3      C  ghi@xyz.com
# 3   Kajal        4      С  jkl@xyz.com

# %%
cus =pd.read_csv("Customer Table Level 1.csv")
cus
# Out:
#     CustomerID                        Company Name       Costumer Name  \
# 0            1                 Alfreds Futterkiste        Maria Anders
# 1            2  Ana Trujillo Emparedados y helados        Ana Trujillo
# 2            3             Antonio Moreno Taqueria      Antonio Moreno
# 3            4                     Around the Horn        Thomas Hardy
# 4            5                   Berglunds snabbkp  Christina Berglund
# ..         ...                                 ...                 ...
# 86          87                      Wartian Herkku    Pirkko Koskitalo
# 87          88              Wellington Importadora       Paula Parente
# 88          89                White Clover Markets      Karl Jablonski
# 89          90                         Wilman Kala     Matti Karttunen
# 90          91                              Wolski             Zbyszek
#
#            City  PostalCode  Country
# 0        Berlin       12209  Germany
# 1   Mexico D.F.        5021   Mexico
# ...

# %%
type (cus)
# Out:
# pandas.core.frame.DataFrame

# %%
type ( cus['CustomerID'] )
# Out:
# pandas.core.series.Series

# %%
cus.index
# Out:
# RangeIndex(start=0, stop=91, step=1)

# %%
cus.columns
# Out:
# Index(['CustomerID', 'Company Name', 'Costumer Name', 'City', 'PostalCode',
#        'Country'],
#       dtype='object')

# %%
cus.to_numpy()
# Out:
# array([[1, 'Alfreds Futterkiste', 'Maria Anders', 'Berlin', 12209,
#         'Germany'],
#        [2, 'Ana Trujillo Emparedados y helados', 'Ana Trujillo',
#         'Mexico D.F.', 5021, 'Mexico'],
#        [3, 'Antonio Moreno Taqueria', 'Antonio Moreno', 'Mexico D.F.',
#         5023, 'Mexico'],
#        [4, 'Around the Horn', 'Thomas Hardy', 'London', 34626, 'UK'],
#        [5, 'Berglunds snabbkp', 'Christina Berglund', 'Lulea', 95822,
#         'Sweden'],
#        [6, 'Blauer See Delikatessen', 'Hanna Moos', 'Mannheim', 68306,
#         'Germany'],
#        [7, 'Blondel pere et fils', 'Frederique Citeaux', 'Strasbourg',
#         67000, 'France'],
#        [8, 'BOlido Comidas preparadas', 'Martin Sommer', 'Madrid', 28023,
#         'Spain'],
#        [9, 'Bon app', 'Laurence Lebihans', 'Marseille', 13008, 'France'],
#        [10, 'Bottom-Dollar Marketse', 'Elizabeth Lincoln', 'Tsawassen',
#         254685, 'Canada'],
# ...

# %%
cus.T
# Out:
#                                 0                                   1   \
# CustomerID                       1                                   2
# Company Name   Alfreds Futterkiste  Ana Trujillo Emparedados y helados
# Costumer Name         Maria Anders                        Ana Trujillo
# City                        Berlin                         Mexico D.F.
# PostalCode                   12209                                5021
# Country                    Germany                              Mexico
#
#                                     2                3                   4   \
# CustomerID                           3                4                   5
# Company Name   Antonio Moreno Taqueria  Around the Horn   Berglunds snabbkp
# Costumer Name           Antonio Moreno     Thomas Hardy  Christina Berglund
# City                       Mexico D.F.           London               Lulea
# PostalCode                        5023            34626               95822
# ...

# %%
cus
# Out:
#     CustomerID                        Company Name       Costumer Name  \
# 0            1                 Alfreds Futterkiste        Maria Anders
# 1            2  Ana Trujillo Emparedados y helados        Ana Trujillo
# 2            3             Antonio Moreno Taqueria      Antonio Moreno
# 3            4                     Around the Horn        Thomas Hardy
# 4            5                   Berglunds snabbkp  Christina Berglund
# ..         ...                                 ...                 ...
# 86          87                      Wartian Herkku    Pirkko Koskitalo
# 87          88              Wellington Importadora       Paula Parente
# 88          89                White Clover Markets      Karl Jablonski
# 89          90                         Wilman Kala     Matti Karttunen
# 90          91                              Wolski             Zbyszek
#
#            City  PostalCode  Country
# 0        Berlin       12209  Germany
# 1   Mexico D.F.        5021   Mexico
# ...

# %%
cus.drop('Company Name',axis=1)
# Out:
#     CustomerID       Costumer Name         City  PostalCode  Country
# 0            1        Maria Anders       Berlin       12209  Germany
# 1            2        Ana Trujillo  Mexico D.F.        5021   Mexico
# 2            3      Antonio Moreno  Mexico D.F.        5023   Mexico
# 3            4        Thomas Hardy       London       34626       UK
# 4            5  Christina Berglund        Lulea       95822   Sweden
# ..         ...                 ...          ...         ...      ...
# 86          87    Pirkko Koskitalo         Oulu       90110  Finland
# 87          88       Paula Parente      Resende       51849   Brazil
# 88          89      Karl Jablonski      Seattle       98128      USA
# 89          90     Matti Karttunen     Helsinki       21240  Finland
# 90          91             Zbyszek        Walla       56189   Poland
#
# [91 rows x 5 columns]

# %%
cus.loc[(48,78), ('Company Name','Costumer Name') ]
# Out:
#                     Company Name     Costumer Name
# 48  Magazzini Alimentari Riuniti  Giovanni Rovelli
# 78            Toms Spezialitaten     Karin Josephs

# %%
cus .loc [tuple((np.arange(48,78))), ('Company Name', 'Costumer Name')]
# Out:
#                     Company Name        Costumer Name
# 48  Magazzini Alimentari Riuniti     Giovanni Rovelli
# 49                  Maison Dewey      Catherine Dewey
# 50                Mere Paillarde       Jean Fresniere
# 51        Morgenstern Gesundkost      Alexander Feuer
# 52                   North/South       Simon Crowther
# 53        Oceano Atlantico Ltda.       Yvonne Moncada
# 54        Old World Delicatessen        Rene Phillips
# 55            Ottilies Kaseladen  Henriette Pfalzheim
# 56             Paris specialites       Marie Bertrand
# 57     Pericles Comidas clasicas  Guillermo Fernandez
# 58              Piccolo und mehr          Georg Pipps
# 59       Princesa Isabel Vinhoss     Isabel de Castro
# 60                   Que Delicia     Bernardo Batista
# 61                 Queen Cozinha       Lucia Carvalho
# 62                    QUICK-Stop          Horst Kloss
# 63                 Rancho grande     Sergio Gutierrez
# ...

# %%
cus .loc [((np.arange(48,78))), ('Company Name', 'Costumer Name')]
# Out:
#                     Company Name        Costumer Name
# 48  Magazzini Alimentari Riuniti     Giovanni Rovelli
# 49                  Maison Dewey      Catherine Dewey
# 50                Mere Paillarde       Jean Fresniere
# 51        Morgenstern Gesundkost      Alexander Feuer
# 52                   North/South       Simon Crowther
# 53        Oceano Atlantico Ltda.       Yvonne Moncada
# 54        Old World Delicatessen        Rene Phillips
# 55            Ottilies Kaseladen  Henriette Pfalzheim
# 56             Paris specialites       Marie Bertrand
# 57     Pericles Comidas clasicas  Guillermo Fernandez
# 58              Piccolo und mehr          Georg Pipps
# 59       Princesa Isabel Vinhoss     Isabel de Castro
# 60                   Que Delicia     Bernardo Batista
# 61                 Queen Cozinha       Lucia Carvalho
# 62                    QUICK-Stop          Horst Kloss
# 63                 Rancho grande     Sergio Gutierrez
# ...

# %%
 employees = {
    1: {"company": "Tech Solutions", "name": "Alice Johnson", "position": "Software Engineer"},
    2: {"company": "Innovate Inc.", "name": "Bob Smith", "position": "Data Scientist"},
    3: {"company": "Creative Minds", "name": "Carol White", "position": "Graphic Designer"},
    4: {"company": "BuildRight", "name": "David Brown", "position": "Project Manager"},
    5: {"company": "FinTech Co.", "name": "Emma Davis", "position": "Financial Analyst"},
    6: {"company": "HealthPlus", "name": "Frank Harris", "position": "Healthcare Consultant"},
    7: {"company": "EduCare", "name": "Grace Lewis", "position": "Curriculum Developer"},
    8: {"company": "GreenEnergy", "name": "Henry Clark", "position": "Environmental Engineer"},
    9: {"company": "SafeHome", "name": "Ivy Walker", "position": "Security Specialist"},
    10: {"company": "MarketPros", "name": "Jack Hall", "position": "Marketing Manager"},
    11: {"company": "Tech Solutions", "name": "Kathy Moore", "position": "Product Manager"},
    12: {"company": "Innovate Inc.", "name": "Larry Scott", "position": "UX Designer"},
    13: {"company": "Creative Minds", "name": "Megan Adams", "position": "Content Writer"},
    14: {"company": "BuildRight", "name": "Nate Carter", "position": "Civil Engineer"},
    15: {"company": "FinTech Co.", "name": "Olivia Mitchell", "position": "Risk Analyst"},
    16: {"company": "HealthPlus", "name": "Paul Nelson", "position": "Pharmacist"},
    17: {"company": "EduCare", "name": "Quinn Rogers", "position": "Instructional Designer"},
    18: {"company": "GreenEnergy", "name": "Rachel Stewart", "position": "Renewable Energy Analyst"},
    19: {"company": "SafeHome", "name": "Sam Turner", "position": "Network Engineer"},
    20: {"company": "MarketPros", "name": "Tina Ward", "position": "Social Media Specialist"},
    21: {"company": "Tech Solutions", "name": "Umar Young", "position": "Systems Analyst"},
    22: {"company": "Innovate Inc.", "name": "Vera King", "position": "Data Analyst"},
    23: {"company": "Creative Minds", "name": "Will Baker", "position": "Art Director"},
    24: {"company": "BuildRight", "name": "Xander Perez", "position": "Construction Manager"},
    25: {"company": "FinTech Co.", "name": "Yara Gonzalez", "position": "Investment Banker"},
    26: {"company": "HealthPlus", "name": "Zane Brooks", "position": "Health Informatics Specialist"},
    27: {"company": "EduCare", "name": "Anna James", "position": "Educational Consultant"},
    28: {"company": "GreenEnergy", "name": "Brian Lee", "position": "Energy Efficiency Expert"},
    29: {"company": "SafeHome", "name": "Clara Wright", "position": "Cybersecurity Analyst"},
    30: {"company": "MarketPros", "name": "Daniel Fisher", "position": "SEO Specialist"},
    31: {"company": "Tech Solutions", "name": "Ella Rivera", "position": "DevOps Engineer"},
    32: {"company": "Innovate Inc.", "name": "Felix Cooper", "position": "Research Scientist"},
    33: {"company": "Creative Minds", "name": "Gina Morris", "position": "Animator"},
    34: {"company": "BuildRight", "name": "Hank Rodriguez", "position": "Architect"},
    35: {"company": "FinTech Co.", "name": "Isla Watson", "position": "Compliance Officer"},
    36: {"company": "HealthPlus", "name": "Jake Bryant", "position": "Clinical Research Coordinator"},
    37: {"company": "EduCare", "name": "Kara Cox", "position": "Academic Advisor"},
    38: {"company": "GreenEnergy", "name": "Leo Campbell", "position": "Sustainability Consultant"},
    39: {"company": "SafeHome", "name": "Maya Edwards", "position": "IT Security Specialist"},
    40: {"company": "MarketPros", "name": "Nina Fox", "position": "Brand Manager"},
    41: {"company": "Tech Solutions", "name": "Oscar Green", "position": "IT Support Specialist"},
    42: {"company": "Innovate Inc.", "name": "Penny Hughes", "position": "Product Designer"},
    43: {"company": "Creative Minds", "name": "Quincy Diaz", "position": "Copywriter"},
    44: {"company": "BuildRight", "name": "Rita King", "position": "Urban Planner"},
    45: {"company": "FinTech Co.", "name": "Sean Lee", "position": "Financial Planner"},
    46: {"company": "HealthPlus", "name": "Tara Morgan", "position": "Public Health Specialist"},
    47: {"company": "EduCare", "name": "Uma Patel", "position": "Education Policy Analyst"},
    48: {"company": "GreenEnergy", "name": "Victor Ramirez", "position": "Environmental Scientist"},
    49: {"company": "SafeHome", "name": "Wendy Scott", "position": "Physical Security Specialist"},
    50: {"company": "MarketPros", "name": "Xena Taylor", "position": "Content Strategist"}
}

print(employees)
# Out:
# {1: {'company': 'Tech Solutions', 'name': 'Alice Johnson', 'position': 'Software Engineer'}, 2: {'company': 'Innovate Inc.', 'name': 'Bob Smith', 'position': 'Data Scientist'}, 3: {'company': 'Creative Minds', 'name': 'Carol White', 'position': 'Graphic Designer'}, 4: {'company': 'BuildRight', 'name': 'David Brown', 'position': 'Project Manager'}, 5: {'company': 'FinTech Co.', 'name': 'Emma Davis', 'position': 'Financial Analyst'}, 6: {'company': 'HealthPlus', 'name': 'Frank Harris', 'position': 'Healthcare Consultant'}, 7: {'company': 'EduCare', 'name': 'Grace Lewis', 'position': 'Curriculum Developer'}, 8: {'company': 'GreenEnergy', 'name': 'Henry Clark', 'position': 'Environmental Engineer'}, 9: {'company': 'SafeHome', 'name': 'Ivy Walker', 'position': 'Security Specialist'}, 10: {'company': 'MarketPros', 'name': 'Jack Hall', 'position': 'Marketing Manager'}, 11: {'company': 'Tech Solutions', 'name': 'Kathy Moore', 'position': 'Product Manager'}, 12: {'company': 'Innovate Inc.', '
# ...

# %%
cd= pd.DataFrame(employees)
cd
# Out:
#                          1               2                 3   \
# company      Tech Solutions   Innovate Inc.    Creative Minds
# name          Alice Johnson       Bob Smith       Carol White
# position  Software Engineer  Data Scientist  Graphic Designer
#
#                        4                  5                      6   \
# company        BuildRight        FinTech Co.             HealthPlus
# name          David Brown         Emma Davis           Frank Harris
# position  Project Manager  Financial Analyst  Healthcare Consultant
#
#                             7                       8                    9   \
# company                EduCare             GreenEnergy             SafeHome
# name               Grace Lewis             Henry Clark           Ivy Walker
# position  Curriculum Developer  Environmental Engineer  Security Specialist
#
#                          10  ...                     41                42  \
# ...

# %%
cd.to_csv('employees.csv', index=False)

# %%
cd.T
# Out:
#            company             name                       position
# 1   Tech Solutions    Alice Johnson              Software Engineer
# 2    Innovate Inc.        Bob Smith                 Data Scientist
# 3   Creative Minds      Carol White               Graphic Designer
# 4       BuildRight      David Brown                Project Manager
# 5      FinTech Co.       Emma Davis              Financial Analyst
# 6       HealthPlus     Frank Harris          Healthcare Consultant
# 7          EduCare      Grace Lewis           Curriculum Developer
# 8      GreenEnergy      Henry Clark         Environmental Engineer
# 9         SafeHome       Ivy Walker            Security Specialist
# 10      MarketPros        Jack Hall              Marketing Manager
# 11  Tech Solutions      Kathy Moore                Product Manager
# 12   Innovate Inc.      Larry Scott                    UX Designer
# 13  Creative Minds      Megan Adams                 Content Writer
# ...
