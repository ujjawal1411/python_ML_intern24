# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import matplotlib as mpl
import seaborn as sns
import os
# %matplotlib inline

# %%
sm= pd.read_csv("titanic.csv")
sm.head()
# Out:
#    survived  pclass     sex   age  sibsp  parch     fare embarked  class  \
# 0         0       3    male  22.0      1      0   7.2500        S  Third
# 1         1       1  female  38.0      1      0  71.2833        C  First
# 2         1       3  female  26.0      0      0   7.9250        S  Third
# 3         1       1  female  35.0      1      0  53.1000        S  First
# 4         0       3    male  35.0      0      0   8.0500        S  Third
#
#      who  adult_male deck  embark_town alive  alone
# 0    man        True  NaN  Southampton    no  False
# 1  woman       False    C    Cherbourg   yes  False
# 2  woman       False  NaN  Southampton   yes   True
# 3  woman       False    C  Southampton   yes  False
# 4    man        True  NaN  Southampton    no   True

# %%
whoVSsex=auto.groupby(["who","sex"]).size().unstack(fill_value=0)
whoVSsex
# Out:
# sex    female  male
# who
# child      43    40
# man         0   537
# woman     271     0

# %%
whoVSsex.plot(kind='bar',stacked=True)
plt.show()

# %%
temp=sm.head()
temp
# Out:
#    survived  pclass     sex   age  sibsp  parch     fare embarked  class  \
# 0         0       3    male  22.0      1      0   7.2500        S  Third
# 1         1       1  female  38.0      1      0  71.2833        C  First
# 2         1       3  female  26.0      0      0   7.9250        S  Third
# 3         1       1  female  35.0      1      0  53.1000        S  First
# 4         0       3    male  35.0      0      0   8.0500        S  Third
#
#      who  adult_male deck  embark_town alive  alone
# 0    man        True  NaN  Southampton    no  False
# 1  woman       False    C    Cherbourg   yes  False
# 2  woman       False  NaN  Southampton   yes   True
# 3  woman       False    C  Southampton   yes  False
# 4    man        True  NaN  Southampton    no   True

# %%
plt.figure(figsize=(20,8))
sns.set(rc={"axes.facecolor":"#FFFFFF","axes.grid":False ,"xtick.labelsize":10, "ytick.labelsize":10})
plt.title("age VS fare")
plt.xlabel("age")
plt.ylabel("fare")
plt.xticks(rotation=45)

sns.lineplot(x=auto["age"],y=auto["fare"] . index.values,color='r')
plt.show()

# %%
def categorize_age(age):
    if age < 18:
        return 'child'
    else:
        return 'adult'
        
df['AgeCategory'] = df['Age'].apply(categorize_age)
survivors = df[df['Survived'] == 1]

male_survivors = survivors[survivors['sex'] == 'male'].shape[0]
female_survivors = survivors[survivors['sex'] == 'female'].shape[0]
child_survivors = survivors[survivors['a'] == 'child'].shape[0]

print( "male_survivors")
print("female_survivors")
print("child_survivors")
